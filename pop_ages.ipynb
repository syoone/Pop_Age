# %%
pwd
# Out:
# '/Users/seongy.yoon/Python/KOSIS'

# %%
import numpy as np
import pandas as pd

# %%
pop_ages = pd.read_csv('연령별인구현황_202106.csv', thousands=',', encoding='cp949')
pop_ages.head()
# Out:
#                           행정구역  2021년06월_계_총인구수  2021년06월_계_연령구간인구수  \
# 0          서울특별시  (1100000000)          9565990             9565990
# 1       서울특별시 종로구 (1111000000)           146029              146029
# 2  서울특별시 종로구 청운효자동(1111051500)            12024               12024
# 3    서울특별시 종로구 사직동(1111053000)             9371                9371
# 4    서울특별시 종로구 삼청동(1111054000)             2498                2498
#
#    2021년06월_계_0세  2021년06월_계_1세  2021년06월_계_2세  2021년06월_계_3세  2021년06월_계_4세  \
# 0          44241          47223          51058          54048          59547
# 1            486            538            563            622            728
# 2             46             52             60             66             87
# 3             26             30             43             47             63
# 4             10              5              5             11             10
#
#    2021년06월_계_5세  2021년06월_계_6세  ...  2021년06월_여_91세  2021년06월_여_92세  \
# ...

# %%
pop_ages.tail()
# Out:
#                               행정구역  2021년06월_계_총인구수  2021년06월_계_연령구간인구수  \
# 3842  제주특별자치도 서귀포시 서홍동(5013058000)            10925               10925
# 3843  제주특별자치도 서귀포시 대륜동(5013059000)            15084               15084
# 3844  제주특별자치도 서귀포시 대천동(5013060000)            13865               13865
# 3845  제주특별자치도 서귀포시 중문동(5013061000)            11563               11563
# 3846  제주특별자치도 서귀포시 예래동(5013062000)             3915                3915
#
#       2021년06월_계_0세  2021년06월_계_1세  2021년06월_계_2세  2021년06월_계_3세  \
# 3842             66             78             98             94
# 3843            104            150            142            147
# 3844            103            121            132            164
# 3845             63             80             77             71
# 3846             12             15             25             16
#
#       2021년06월_계_4세  2021년06월_계_5세  2021년06월_계_6세  ...  2021년06월_여_91세  \
# ...

# %%
pop_ages = pop_ages.melt(id_vars="행정구역")
pop_ages.head()
# Out:
#                           행정구역         variable    value
# 0          서울특별시  (1100000000)  2021년06월_계_총인구수  9565990
# 1       서울특별시 종로구 (1111000000)  2021년06월_계_총인구수   146029
# 2  서울특별시 종로구 청운효자동(1111051500)  2021년06월_계_총인구수    12024
# 3    서울특별시 종로구 사직동(1111053000)  2021년06월_계_총인구수     9371
# 4    서울특별시 종로구 삼청동(1111054000)  2021년06월_계_총인구수     2498

# %%
pop_ages.to_csv('df.csv', index = 'True', encoding='cp949')

# %%
pop_ages.tail()
# Out:
#                                  행정구역            variable  value
# 1188718  제주특별자치도 서귀포시 서홍동(5013058000)  2021년06월_여_100세 이상      3
# 1188719  제주특별자치도 서귀포시 대륜동(5013059000)  2021년06월_여_100세 이상      5
# 1188720  제주특별자치도 서귀포시 대천동(5013060000)  2021년06월_여_100세 이상      3
# 1188721  제주특별자치도 서귀포시 중문동(5013061000)  2021년06월_여_100세 이상      6
# 1188722  제주특별자치도 서귀포시 예래동(5013062000)  2021년06월_여_100세 이상      0

# %%
pop_ages.columns
# Out:
# Index(['행정구역', 'variable', 'value'], dtype='object')

# %%
pop_ages.rename(columns={'행정구역':'Region','variable':'Ages', 'value':'Population'}, inplace=True)
pop_ages.head()
# Out:
#                         Region             Ages  Population
# 0          서울특별시  (1100000000)  2021년06월_계_총인구수     9565990
# 1       서울특별시 종로구 (1111000000)  2021년06월_계_총인구수      146029
# 2  서울특별시 종로구 청운효자동(1111051500)  2021년06월_계_총인구수       12024
# 3    서울특별시 종로구 사직동(1111053000)  2021년06월_계_총인구수        9371
# 4    서울특별시 종로구 삼청동(1111054000)  2021년06월_계_총인구수        2498

# %%
type(pop_ages)
# Out:
# pandas.core.frame.DataFrame

# %%
pop_ages['Region'].str.split(" ")
# Out:
# 0                   [서울특별시, , (1100000000)]
# 1                [서울특별시, 종로구, (1111000000)]
# 2           [서울특별시, 종로구, 청운효자동(1111051500)]
# 3             [서울특별시, 종로구, 사직동(1111053000)]
# 4             [서울특별시, 종로구, 삼청동(1111054000)]
#                          ...
# 1188718    [제주특별자치도, 서귀포시, 서홍동(5013058000)]
# 1188719    [제주특별자치도, 서귀포시, 대륜동(5013059000)]
# 1188720    [제주특별자치도, 서귀포시, 대천동(5013060000)]
# 1188721    [제주특별자치도, 서귀포시, 중문동(5013061000)]
# 1188722    [제주특별자치도, 서귀포시, 예래동(5013062000)]
# Name: Region, Length: 1188723, dtype: object

# %%
pop_ages['Region'].str.split(" ", expand=True)
# Out:
#                0     1                  2     3
# 0          서울특별시             (1100000000)  None
# 1          서울특별시   종로구       (1111000000)  None
# 2          서울특별시   종로구  청운효자동(1111051500)  None
# 3          서울특별시   종로구    사직동(1111053000)  None
# 4          서울특별시   종로구    삼청동(1111054000)  None
# ...          ...   ...                ...   ...
# 1188718  제주특별자치도  서귀포시    서홍동(5013058000)  None
# 1188719  제주특별자치도  서귀포시    대륜동(5013059000)  None
# 1188720  제주특별자치도  서귀포시    대천동(5013060000)  None
# 1188721  제주특별자치도  서귀포시    중문동(5013061000)  None
# 1188722  제주특별자치도  서귀포시    예래동(5013062000)  None
#
# [1188723 rows x 4 columns]

# %%
pop_ages['City'] = pop_ages['Region'].str.split(" ", expand=True)[0]
pop_ages['Gu']   = pop_ages['Region'].str.split(" ", expand=True)[1]
pop_ages['dong'] = pop_ages['Region'].str.split(" ", expand=True)[2]
pop_ages.head()
# Out:
#                         Region             Ages  Population   City   Gu  \
# 0          서울특별시  (1100000000)  2021년06월_계_총인구수     9565990  서울특별시
# 1       서울특별시 종로구 (1111000000)  2021년06월_계_총인구수      146029  서울특별시  종로구
# 2  서울특별시 종로구 청운효자동(1111051500)  2021년06월_계_총인구수       12024  서울특별시  종로구
# 3    서울특별시 종로구 사직동(1111053000)  2021년06월_계_총인구수        9371  서울특별시  종로구
# 4    서울특별시 종로구 삼청동(1111054000)  2021년06월_계_총인구수        2498  서울특별시  종로구
#
#                 dong
# 0       (1100000000)
# 1       (1111000000)
# 2  청운효자동(1111051500)
# 3    사직동(1111053000)
# 4    삼청동(1111054000)

# %%
pop_ages['dong'].str.split('(', expand=True)
# Out:
#              0            1
# 0               1100000000)
# 1               1111000000)
# 2        청운효자동  1111051500)
# 3          사직동  1111053000)
# 4          삼청동  1111054000)
# ...        ...          ...
# 1188718    서홍동  5013058000)
# 1188719    대륜동  5013059000)
# 1188720    대천동  5013060000)
# 1188721    중문동  5013061000)
# 1188722    예래동  5013062000)
#
# [1188723 rows x 2 columns]

# %%
pop_ages['Dong'] = pop_ages['dong'].str.split('(', expand=True)[0]
pop_ages['Code'] = pop_ages['dong'].str.split('(', expand=True)[1]
pop_ages.head()
# Out:
#                         Region             Ages  Population   City   Gu  \
# 0          서울특별시  (1100000000)  2021년06월_계_총인구수     9565990  서울특별시
# 1       서울특별시 종로구 (1111000000)  2021년06월_계_총인구수      146029  서울특별시  종로구
# 2  서울특별시 종로구 청운효자동(1111051500)  2021년06월_계_총인구수       12024  서울특별시  종로구
# 3    서울특별시 종로구 사직동(1111053000)  2021년06월_계_총인구수        9371  서울특별시  종로구
# 4    서울특별시 종로구 삼청동(1111054000)  2021년06월_계_총인구수        2498  서울특별시  종로구
#
#                 dong   Dong         Code
# 0       (1100000000)         1100000000)
# 1       (1111000000)         1111000000)
# 2  청운효자동(1111051500)  청운효자동  1111051500)
# 3    사직동(1111053000)    사직동  1111053000)
# 4    삼청동(1111054000)    삼청동  1111054000)

# %%
pop_ages['Code']
# Out:
# 0          1100000000)
# 1          1111000000)
# 2          1111051500)
# 3          1111053000)
# 4          1111054000)
#               ...
# 1188718    5013058000)
# 1188719    5013059000)
# 1188720    5013060000)
# 1188721    5013061000)
# 1188722    5013062000)
# Name: Code, Length: 1188723, dtype: object

# %%
pop_ages['Code'].str.split(")")
pop_ages.head()
# Out:
#                         Region             Ages  Population   City   Gu  \
# 0          서울특별시  (1100000000)  2021년06월_계_총인구수     9565990  서울특별시
# 1       서울특별시 종로구 (1111000000)  2021년06월_계_총인구수      146029  서울특별시  종로구
# 2  서울특별시 종로구 청운효자동(1111051500)  2021년06월_계_총인구수       12024  서울특별시  종로구
# 3    서울특별시 종로구 사직동(1111053000)  2021년06월_계_총인구수        9371  서울특별시  종로구
# 4    서울특별시 종로구 삼청동(1111054000)  2021년06월_계_총인구수        2498  서울특별시  종로구
#
#                 dong   Dong         Code
# 0       (1100000000)         1100000000)
# 1       (1111000000)         1111000000)
# 2  청운효자동(1111051500)  청운효자동  1111051500)
# 3    사직동(1111053000)    사직동  1111053000)
# 4    삼청동(1111054000)    삼청동  1111054000)

# %%
pop_ages['Code'].str[:-1]
# Out:
# 0          1100000000
# 1          1111000000
# 2          1111051500
# 3          1111053000
# 4          1111054000
#               ...
# 1188718    5013058000
# 1188719    5013059000
# 1188720    5013060000
# 1188721    5013061000
# 1188722    5013062000
# Name: Code, Length: 1188723, dtype: object

# %%
pop_ages['Code'] = pop_ages['Code'].str[:-1]
pop_ages.head()
# Out:
#                         Region             Ages  Population   City   Gu  \
# 0          서울특별시  (1100000000)  2021년06월_계_총인구수     9565990  서울특별시
# 1       서울특별시 종로구 (1111000000)  2021년06월_계_총인구수      146029  서울특별시  종로구
# 2  서울특별시 종로구 청운효자동(1111051500)  2021년06월_계_총인구수       12024  서울특별시  종로구
# 3    서울특별시 종로구 사직동(1111053000)  2021년06월_계_총인구수        9371  서울특별시  종로구
# 4    서울특별시 종로구 삼청동(1111054000)  2021년06월_계_총인구수        2498  서울특별시  종로구
#
#                 dong   Dong        Code
# 0       (1100000000)         1100000000
# 1       (1111000000)         1111000000
# 2  청운효자동(1111051500)  청운효자동  1111051500
# 3    사직동(1111053000)    사직동  1111053000
# 4    삼청동(1111054000)    삼청동  1111054000

# %%
pop_ages.drop('dong',axis=1, inplace=True)

# %%
pop_ages['Ages'].str.split('_',expand=True)
# Out:
#                 0  1        2
# 0        2021년06월  계     총인구수
# 1        2021년06월  계     총인구수
# 2        2021년06월  계     총인구수
# 3        2021년06월  계     총인구수
# 4        2021년06월  계     총인구수
# ...           ... ..      ...
# 1188718  2021년06월  여  100세 이상
# 1188719  2021년06월  여  100세 이상
# 1188720  2021년06월  여  100세 이상
# 1188721  2021년06월  여  100세 이상
# 1188722  2021년06월  여  100세 이상
#
# [1188723 rows x 3 columns]

# %%
pop_ages['Year'] = pop_ages['Ages'].str.split('_',expand=True)[0]
pop_ages['Sex']  = pop_ages['Ages'].str.split('_',expand=True)[1]
pop_ages['Age']  = pop_ages['Ages'].str.split('_',expand=True)[2]
pop_ages.head()
# Out:
#                         Region             Ages  Population   City   Gu  \
# 0          서울특별시  (1100000000)  2021년06월_계_총인구수     9565990  서울특별시
# 1       서울특별시 종로구 (1111000000)  2021년06월_계_총인구수      146029  서울특별시  종로구
# 2  서울특별시 종로구 청운효자동(1111051500)  2021년06월_계_총인구수       12024  서울특별시  종로구
# 3    서울특별시 종로구 사직동(1111053000)  2021년06월_계_총인구수        9371  서울특별시  종로구
# 4    서울특별시 종로구 삼청동(1111054000)  2021년06월_계_총인구수        2498  서울특별시  종로구
#
#     Dong        Code      Year Sex   Age
# 0         1100000000  2021년06월   계  총인구수
# 1         1111000000  2021년06월   계  총인구수
# 2  청운효자동  1111051500  2021년06월   계  총인구수
# 3    사직동  1111053000  2021년06월   계  총인구수
# 4    삼청동  1111054000  2021년06월   계  총인구수

# %%
pop_ages.drop(['Region','Ages'],axis=1, inplace=True)
pop_ages.head()
# Out:
#    Population   City   Gu   Dong        Code      Year Sex   Age
# 0     9565990  서울특별시              1100000000  2021년06월   계  총인구수
# 1      146029  서울특별시  종로구         1111000000  2021년06월   계  총인구수
# 2       12024  서울특별시  종로구  청운효자동  1111051500  2021년06월   계  총인구수
# 3        9371  서울특별시  종로구    사직동  1111053000  2021년06월   계  총인구수
# 4        2498  서울특별시  종로구    삼청동  1111054000  2021년06월   계  총인구수

# %%
pop_ages['Year'] = pop_ages['Year'].str[0:4]
pop_ages.head()
# Out:
#    Population   City   Gu   Dong        Code  Year Sex   Age
# 0     9565990  서울특별시              1100000000  2021   계  총인구수
# 1      146029  서울특별시  종로구         1111000000  2021   계  총인구수
# 2       12024  서울특별시  종로구  청운효자동  1111051500  2021   계  총인구수
# 3        9371  서울특별시  종로구    사직동  1111053000  2021   계  총인구수
# 4        2498  서울특별시  종로구    삼청동  1111054000  2021   계  총인구수

# %%
pop_ages['Dong'].unique()
# Out:
# array(['', '청운효자동', '사직동', ..., '대천동', '중문동', '예래동'], dtype=object)

# %%
pop_ages[(pop_ages['Gu'] != '')&(pop_ages['Dong'] == '')]
# Out:
#          Population     City    Gu Dong        Code  Year Sex      Age
# 1            146029    서울특별시   종로구       1111000000  2021   계     총인구수
# 19           123016    서울특별시    중구       1114000000  2021   계     총인구수
# 35           226378    서울특별시   용산구       1117000000  2021   계     총인구수
# 52           289162    서울특별시   성동구       1120000000  2021   계     총인구수
# 70           342481    서울특별시   광진구       1121500000  2021   계     총인구수
# ...             ...      ...   ...  ...         ...   ...  ..      ...
# 1188634          14     경상남도   함양군       4887000000  2021   여  100세 이상
# 1188646          19     경상남도   거창군       4888000000  2021   여  100세 이상
# 1188659          27     경상남도   합천군       4889000000  2021   여  100세 이상
# 1188678         121  제주특별자치도   제주시       5011000000  2021   여  100세 이상
# 1188705          65  제주특별자치도  서귀포시       5013000000  2021   여  100세 이상
#
# [74469 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
plt.rc("font", family="AppleGothic")

# %%
df_all = pop_ages.copy()
df_city = pop_ages[pop_ages['Dong'] == '']

# %%
pop_city = pop_ages[(pop_ages['Gu'] == '')&(pop_ages['Dong'] == '')&(pop_ages['Age'] != '연령구간인구수')&(pop_ages['Age'] != '총인구수')]
pop_city.head()
# Out:
#       Population   City Gu Dong        Code  Year Sex Age
# 7694       44241  서울특별시          1100000000  2021   계  0세
# 8145       14124  부산광역시          2600000000  2021   계  0세
# 8367       10436  대구광역시          2700000000  2021   계  0세
# 8519       14628  인천광역시          2800000000  2021   계  0세
# 8693        7493  광주광역시          2900000000  2021   계  0세

# %%
pop_city['Age'].str.replace('세 이상','')
pop_city['Age'].str.replace('세','')
pop_city.head()
# Out:
#       Population   City Gu Dong        Code  Year Sex Age
# 7694       44241  서울특별시          1100000000  2021   계  0세
# 8145       14124  부산광역시          2600000000  2021   계  0세
# 8367       10436  대구광역시          2700000000  2021   계  0세
# 8519       14628  인천광역시          2800000000  2021   계  0세
# 8693        7493  광주광역시          2900000000  2021   계  0세

# %%
pd.pivot_table(pop_city, index=['City','Age'])
# Out:
#                Population
# City Age
# 강원도  0세       4884.666667
#      100세 이상   308.000000
#      10세      8904.666667
#      11세      8364.000000
#      12세      8451.333333
# ...                   ...
# 충청북도 96세       260.000000
#      97세       158.666667
#      98세       182.666667
#      99세       121.333333
#      9세       9904.000000
#
# [1919 rows x 1 columns]

# %%
pop_city.to_csv('df_city.csv', index = 'True', encoding='cp949')

# %%
pop_gu = pop_ages[(pop_ages['Gu'] != '')&(pop_ages['Dong'] == '')&(pop_ages['Age'] != '연령구간인구수')&(pop_ages['Age'] != '총인구수')]
pop_gu.head()
# Out:
#       Population   City   Gu Dong        Code  Year Sex Age
# 7695         486  서울특별시  종로구       1111000000  2021   계  0세
# 7713         578  서울특별시   중구       1114000000  2021   계  0세
# 7729        1099  서울특별시  용산구       1117000000  2021   계  0세
# 7746        1803  서울특별시  성동구       1120000000  2021   계  0세
# 7764        1403  서울특별시  광진구       1121500000  2021   계  0세

# %%
pop_gu.to_csv('df_gu.csv', index = 'True', encoding='cp949')

# %%
pop_dong = pop_ages[(pop_ages['Dong'] != '')&(pop_ages['Age'] != '연령구간인구수')&(pop_ages['Age'] != '총인구수')]
pop_dong.head()
# Out:
#       Population   City   Gu   Dong        Code  Year Sex Age
# 7696          46  서울특별시  종로구  청운효자동  1111051500  2021   계  0세
# 7697          26  서울특별시  종로구    사직동  1111053000  2021   계  0세
# 7698          10  서울특별시  종로구    삼청동  1111054000  2021   계  0세
# 7699          20  서울특별시  종로구    부암동  1111055000  2021   계  0세
# 7700          76  서울특별시  종로구    평창동  1111056000  2021   계  0세

# %%
pop_dong.to_csv('df_dong.csv', index = 'True', encoding='cp949')

# %%
pop_ages['Age'].unique()
# Out:
# array(['총인구수', '연령구간인구수', '0세', '1세', '2세', '3세', '4세', '5세', '6세', '7세',
#        '8세', '9세', '10세', '11세', '12세', '13세', '14세', '15세', '16세', '17세',
#        '18세', '19세', '20세', '21세', '22세', '23세', '24세', '25세', '26세',
#        '27세', '28세', '29세', '30세', '31세', '32세', '33세', '34세', '35세',
#        '36세', '37세', '38세', '39세', '40세', '41세', '42세', '43세', '44세',
#        '45세', '46세', '47세', '48세', '49세', '50세', '51세', '52세', '53세',
#        '54세', '55세', '56세', '57세', '58세', '59세', '60세', '61세', '62세',
#        '63세', '64세', '65세', '66세', '67세', '68세', '69세', '70세', '71세',
#        '72세', '73세', '74세', '75세', '76세', '77세', '78세', '79세', '80세',
#        '81세', '82세', '83세', '84세', '85세', '86세', '87세', '88세', '89세',
#        '90세', '91세', '92세', '93세', '94세', '95세', '96세', '97세', '98세',
#        '99세', '100세 이상'], dtype=object)

# %%
pop_ages[pop_ages['Age']=='연령구간인구수'].sum()
# Out:
# Population                                            328393798
# City          서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서...
# Gu            종로구종로구종로구종로구종로구종로구종로구종로구종로구종로구종로구종로구종로구종로구종로구종...
# Dong          청운효자동사직동삼청동부암동평창동무악동교남동가회동종로1.2.3.4가동종로5.6가동이화...
# Year          2021202120212021202120212021202120212021202120...
# Sex           계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계계...
# Age           연령구간인구수연령구간인구수연령구간인구수연령구간인구수연령구간인구수연령구간인구수연령구간...
# dtype: object

# %%
pop_city[pop_city['Age']!= '총인구수']
# Out:
#          Population     City Gu Dong        Code  Year Sex      Age
# 7694          44241    서울특별시          1100000000  2021   계       0세
# 8145          14124    부산광역시          2600000000  2021   계       0세
# 8367          10436    대구광역시          2700000000  2021   계       0세
# 8519          14628    인천광역시          2800000000  2021   계       0세
# 8693           7493    광주광역시          2900000000  2021   계       0세
# ...             ...      ... ..  ...         ...   ...  ..      ...
# 1187362         442     전라북도          4500000000  2021   여  100세 이상
# 1187624         533     전라남도          4600000000  2021   여  100세 이상
# 1187970         557     경상북도          4700000000  2021   여  100세 이상
# 1188340         417     경상남도          4800000000  2021   여  100세 이상
# 1188677         186  제주특별자치도          5000000000  2021   여  100세 이상
#
# [6060 rows x 8 columns]

# %%
pop_city['Age'] = pop_city['Age'].str.split('세',expand=True)[0]

# %%
pop_city.head()
pop_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6060 entries, 7694 to 1188677
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Population  6060 non-null   int64
#  1   City        6060 non-null   object
#  2   Gu          6060 non-null   object
#  3   Dong        6060 non-null   object
#  4   Code        6060 non-null   object
#  5   Year        6060 non-null   object
#  6   Sex         6060 non-null   object
#  7   Age         6060 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 555.1+ KB

# %%
pop_city[['Age','Population']] = pop_city[['Age','Population']].astype(int)
pop_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6060 entries, 7694 to 1188677
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Population  6060 non-null   int64
#  1   City        6060 non-null   object
#  2   Gu          6060 non-null   object
#  3   Dong        6060 non-null   object
#  4   Code        6060 non-null   object
#  5   Year        6060 non-null   object
#  6   Sex         6060 non-null   object
#  7   Age         6060 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 555.1+ KB

# %%
pd.pivot_table(pop_city, index=['City','Age'])
# Out:
#            Population
# City Age
# 강원도  0    4884.666667
#      1    5582.000000
#      2    5751.333333
#      3    6149.333333
#      4    6722.666667
# ...               ...
# 충청북도 96    260.000000
#      97    158.666667
#      98    182.666667
#      99    121.333333
#      100   210.000000
#
# [1919 rows x 1 columns]

# %%
df_SL = pop_city[(pop_city['City'] == '서울특별시')&(pop_city['Sex'] == '계')]
df_JN = pop_city[(pop_city['City'] == '전라남도' )&(pop_city['Sex'] == '계')]
df_DJ = pop_city[(pop_city['City'] == '대전광역시')&(pop_city['Sex'] == '계')]

# %%
# 서울특별시 총인구
total = pop_ages[(pop_ages['Gu']=='')&(pop_ages['Dong']=='')&(pop_ages['Ages']=='2021년06월_계_총인구수')]
total.head()
# Out:
#                   Region             Ages  Population   City Gu          dong  \
# 0    서울특별시  (1100000000)  2021년06월_계_총인구수     9565990  서울특별시     (1100000000)
# 451  부산광역시  (2600000000)  2021년06월_계_총인구수     3364358  부산광역시     (2600000000)
# 673  대구광역시  (2700000000)  2021년06월_계_총인구수     2397646  대구광역시     (2700000000)
# 825  인천광역시  (2800000000)  2021년06월_계_총인구수     2936367  인천광역시     (2800000000)
# 999  광주광역시  (2900000000)  2021년06월_계_총인구수     1442647  광주광역시     (2900000000)
#
#     Dong         Code
# 0         1100000000)
# 451       2600000000)
# 673       2700000000)
# 825       2800000000)
# 999       2900000000)

# %%
total.drop(['Region','Ages','Gu','dong','Dong','Code'],axis=1,inplace=True)
total.head()
# Out:
# /Users/seongy.yoon/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      Population   City
# 0       9565990  서울특별시
# 451     3364358  부산광역시
# 673     2397646  대구광역시
# 825     2936367  인천광역시
# 999     1442647  광주광역시

# %%
pop_SL = total[total['City']=='서울특별시']
pop_DJ = total[total['City']=='대전광역시']
pop_JN = total[total['City']=='전라남도']
pop_SL['Population']
# Out:
# 0    9565990
# Name: Population, dtype: int64

# %%
df_SL.head()
# Out:
#        Population   City Gu Dong        Code  Year Sex  Age
# 7694        44241  서울특별시          1100000000  2021   계    0
# 11541       47223  서울특별시          1100000000  2021   계    1
# 15388       51058  서울특별시          1100000000  2021   계    2
# 19235       54048  서울특별시          1100000000  2021   계    3
# 23082       59547  서울특별시          1100000000  2021   계    4

# %%
df_SL['Population'] = df_SL['Population']/pop_SL['Population'].values
# Out:
# /Users/seongy.yoon/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_DJ['Population'] = df_DJ['Population']/pop_DJ['Population'].values
# Out:
# /Users/seongy.yoon/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_JN['Population'] = df_JN['Population']/pop_JN['Population'].values
# Out:
# /Users/seongy.yoon/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(15,6))
sns.lineplot(data=df_SL, x='Age', y='Population', palette ='rocket', ci=None, hue='City')
sns.lineplot(data=df_DJ, x='Age', y='Population', palette ='magma' , ci=None, hue='City')
sns.lineplot(data=df_JN, x='Age', y='Population', palette ='crest' , ci=None, hue='City')

# %%
import seaborn as sns

# %%
df = pop_city[(pop_city['City'] == '서울특별시')]
plt.figure(figsize=(15,4))
sns.lineplot(data=df, x='Age', y='Population', ci=None, hue='Sex')

# %%
df = pop_city[(pop_city['Sex'] == '계')]
plt.figure(figsize=(15,4))
sns.lineplot(data=df, x='Age', y='Population', ci=None, hue='City')

# %%
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False

# %%
city = '대전광역시'
df_m = pop_city[(pop_city['City'] == city)&(pop_city['Sex'] == '남')]
df_f = pop_city[(pop_city['City'] == city)&(pop_city['Sex'] == '여')]
df_f['Population'] = -df_f['Population']
# Out:
# /Users/seongy.yoon/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
plt.figure(figsize=(15,10))
plt.barh(df_m['Age'],df_m['Population'],label='남자')
plt.barh(df_f['Age'],df_f['Population'],label='여자')
# Out:
# <BarContainer object of 101 artists>

# %%
df = pop_city[(pop_city['City'] == '서울특별시')&(pop_city['Sex'] == '계')]
df.set_index(['Age']).plot.bar(figsize=(15,4))

# %%
df = pop_city[(pop_city['City'] == '전라남도')&(pop_city['Sex'] == '계')]
df.set_index(['Age']).plot.bar(figsize=(15,4))

# %%
df = pop_city[(pop_city['City'] == '전라남도')&(pop_city['Sex'] == '남')]
df.set_index(['Age']).plot.bar(figsize=(15,4))

# %%
df = pop_city[(pop_city['City'] == '전라남도')&(pop_city['Sex'] == '여')]
df.set_index(['Age']).plot.bar(figsize=(15,4))

# %%
cities = ['서울특별시','경기도','인천광역시','충청북도','충청남도','세종특별자치시','대전광역시','전라북도','전라남도',
          '광주광역시','경상북도','경상남도','대구광역시','부산광역시','울산광역시','제주특별자치도','강원도']
pop_ages['Region'].isin(cities)
